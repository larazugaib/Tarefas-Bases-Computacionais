# %% [markdown]
# # Lara Zugaib - Tarefa 10

# %% [markdown]
# ## 1) Para este item você deverá usar o arquivo com todos os resultados do campeonato Brasileiro de futebol de 2018.

# %% [markdown]
# ## a) Calcule (e mostre o resultado) a porcentagem de jogos que o time da casa (mandante) ganhou o jogo.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

jogo = pd.read_csv('https://raw.githubusercontent.com/BMClab/BasesComputacionais/master/dados/tabelaBrasileirao2018.csv')
jogo
# Out:
#            Data  Turno         Mandante  Placar do Mandante  \
# 0    14/04/2018      1         Cruzeiro                   0
# 1    14/04/2018      1          Vitória                   2
# 2    14/04/2018      1           Santos                   2
# 3    15/04/2018      1  América Mineiro                   3
# 4    15/04/2018      1    Internacional                   2
# ..          ...    ...              ...                 ...
# 375   2/12/2018      2       Fluminense                   1
# 376   2/12/2018      2            Ceará                   0
# 377   2/12/2018      2        Palmeiras                   3
# 378   2/12/2018      2           Grêmio                   1
# 379   2/12/2018      2            Sport                   2
#
#      Placar do Visitante        Visitante  \
# 0                      1           Grêmio
# 1                      2         Flamengo
# 2                      0            Ceará
# 3                      0            Sport
# ...

# %%
vitória = jogo.query('`Placar do Mandante` > `Placar do Visitante`')
vitória
# Out:
#            Data  Turno         Mandante  Placar do Mandante  \
# 2    14/04/2018      1           Santos                   2
# 3    15/04/2018      1  América Mineiro                   3
# 4    15/04/2018      1    Internacional                   2
# 5    15/04/2018      1    Vasco da Gama                   2
# 6    15/04/2018      1      Corinthians                   2
# ..          ...    ...              ...                 ...
# 373   2/12/2018      2      Chapecoense                   1
# 375   2/12/2018      2       Fluminense                   1
# 377   2/12/2018      2        Palmeiras                   3
# 378   2/12/2018      2           Grêmio                   1
# 379   2/12/2018      2            Sport                   2
#
#      Placar do Visitante         Visitante  \
# 2                      0             Ceará
# 3                      0             Sport
# 4                      0             Bahia
# 5                      1  Atlético Mineiro
# ...

# %%
print('Total de partidas disputadas:', len(jogo))
# Out:
# Total de partidas disputadas: 380

# %%
print('Vitórias do mandante:', len(vitória), 'jogos')
# Out:
# Vitórias do mandante: 202 jogos

# %%
print('porcentagem de jogos vencidos pelo mandante:', int(len(vitória)/len(jogo)*100),"%")
# Out:
# porcentagem de jogos vencidos pelo mandante: 53 %

# %% [markdown]
# ## b) Calcule (e mostre o resultado) a porcentagem de jogos que o time da casa (mandante) não perdeu o jogo.

# %%
x = jogo.query('`Placar do Mandante` >= `Placar do Visitante`')
x
# Out:
#            Data  Turno         Mandante  Placar do Mandante  \
# 1    14/04/2018      1          Vitória                   2
# 2    14/04/2018      1           Santos                   2
# 3    15/04/2018      1  América Mineiro                   3
# 4    15/04/2018      1    Internacional                   2
# 5    15/04/2018      1    Vasco da Gama                   2
# ..          ...    ...              ...                 ...
# 375   2/12/2018      2       Fluminense                   1
# 376   2/12/2018      2            Ceará                   0
# 377   2/12/2018      2        Palmeiras                   3
# 378   2/12/2018      2           Grêmio                   1
# 379   2/12/2018      2            Sport                   2
#
#      Placar do Visitante         Visitante  \
# 1                      2          Flamengo
# 2                      0             Ceará
# 3                      0             Sport
# 4                      0             Bahia
# ...

# %%
print('Total de partidas disputadas:', len(jogo))
# Out:
# Total de partidas disputadas: 380

# %%
print('Jogos em que o mandante não perdeu:', len(x), 'jogos')
# Out:
# Jogos em que o mandante não perdeu: 312 jogos

# %%
print('Porcetagem de jogos em que o mandante não perdeu:', int(len(x)/len(jogo)*100), "%")
# Out:
# Porcetagem de jogos em que o mandante não perdeu: 82 %

# %% [markdown]
# ##2) Para este item você deverá usar o arquivo com a taxa de inflação mensal (IGP-DI) no Brasil de fevereiro de 1944 a junho de 2019 (dados disponibilizados por Ipeadata).

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
inflação = pd.read_csv('https://raw.githubusercontent.com/BMClab/BasesComputacionais/master/dados/inflacaoMensal.csv')
inflação
# Out:
#       Ano  Mês  Inflação
# 0    1944    2      1.45
# 1    1944    3      1.43
# 2    1944    4      1.41
# 3    1944    5      1.39
# 4    1944    6      1.37
# ..    ...  ...       ...
# 900  2019    2      1.25
# 901  2019    3      1.07
# 902  2019    4      0.90
# 903  2019    5      0.40
# 904  2019    6      0.63
#
# [905 rows x 3 columns]

# %% [markdown]
# ##a) Faça um gráfico da taxa de inflação mensal em função do tempo.

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(inflação['Ano'],
         inflação['Inflação'],
         marker ='', linestyle = '-')
plt.grid()
plt.show()

# %% [markdown]
# ## Questão 3

# %% [markdown]
# Para este item você pode usar esse histórico de visualização do Netflix ou, se você tiver acesso ao Netflix, usar o seu histórico (após entrar com a sua senha, role até o final da página e clique em "Baixar tudo").
#
# Mostre quais são os 10 programas mais vistos.

# %%
netflix = pd.read_csv('https://raw.githubusercontent.com/BMClab/BasesComputacionais/master/dados/netflix.csv')
netflix
# Out:
#                                                  Title        Date
# 0          The Crown: Temporada 4: O teste de Balmoral  06/03/2021
# 1                The Crown: Temporada 4: Guarda-costas  05/03/2021
# 2    A Guerra dos Samurais: Temporada 1: A ascensão...  02/03/2021
# 3                                      Professor Polvo  27/02/2021
# 4    Star Trek: Discovery: Temporada 3: Minha Esper...  23/01/2021
# ..                                                 ...         ...
# 869                                      Os miseráveis  06/07/2013
# 870  Além da imaginação (Série original): Temporada...  06/07/2013
# 871  Além da imaginação (Série original): Temporada...  05/07/2013
# 872                                      Jogos Vorazes  04/07/2013
# 873                 Arquivo X: Temporada 1: Episódio 1  04/07/2013
#
# [874 rows x 2 columns]

# %%
import pandas as pd
netflix['Categoria'] = 'Filme'  
netflix['Categoria'][netflix['Title'].str.contains(": Temporada|: Stranger|: Parte")] = 'Série'
netflix['Programa'] = netflix['Title']  
netflix[['Programa','Episódio']] = netflix[netflix['Categoria']=='Série']['Title'].str.split(pat = ': Temporada|: Stranger Things|: Parte', expand = True, n = 1)   
netflix.loc[netflix['Categoria']=='Filme', 'Programa'] = netflix.loc[netflix['Categoria']=='Filme', 'Title']  
netflix = netflix.drop(columns = 'Title')

mais_vistos = netflix['Programa'].value_counts()
mais_vistos

mais_vistos.head(10)
# Out:
# House of Cards                           73
# Jornada nas Estrelas: A nova geração     64
# Star Trek: Enterprise                    63
# Jornada nas Estrelas: Deep Space Nine    46
# Star Trek: Discovery                     42
# Jornada nas estrelas                     34
# The Crown                                32
# Cobra Kai                                30
# Aggretsuko                               28
# Downton Abbey                            25
# Name: Programa, dtype: int64

# %% [markdown]
# Em qual mês do ano foi assistido mais programas?

# %%
import pandas as pd

netflix['Date'] = pd.to_datetime(netflix['Date'], format = '%d/%m/%Y')
netflix

netflix = netflix.sort_values(['Date'])
netflix

mes_mais_assistido = (netflix['Date'].dt.month)
mes_mais_assistido

mes_mais_assistido.head(1)
# Out:
# 873    7
# Name: Date, dtype: int64

# %% [markdown]
# ## 4 Questão
# Para este item você deverá usar o arquivo com todos os resultados do campeonato Brasileiro de futebol de 2018 (tabelaBrasileirao2018.csv encontrado na pasta aula5/dados) (dados obtidos desta e desta página da Wikipedia).
#
# Calcule qual foi a média de Renda para cada Estádio.

# %%
tabela = pd.read_csv('https://raw.githubusercontent.com/BMClab/BasesComputacionais/master/dados/tabelaBrasileirao2018.csv')
tabela
# Out:
#            Data  Turno         Mandante  Placar do Mandante  \
# 0    14/04/2018      1         Cruzeiro                   0
# 1    14/04/2018      1          Vitória                   2
# 2    14/04/2018      1           Santos                   2
# 3    15/04/2018      1  América Mineiro                   3
# 4    15/04/2018      1    Internacional                   2
# ..          ...    ...              ...                 ...
# 375   2/12/2018      2       Fluminense                   1
# 376   2/12/2018      2            Ceará                   0
# 377   2/12/2018      2        Palmeiras                   3
# 378   2/12/2018      2           Grêmio                   1
# 379   2/12/2018      2            Sport                   2
#
#      Placar do Visitante        Visitante  \
# 0                      1           Grêmio
# 1                      2         Flamengo
# 2                      0            Ceará
# 3                      0            Sport
# ...

# %%
estádios = tabela['Estádio']
estádios
# Out:
# 0           Estádio Mineirão, Belo Horizonte
# 1                 Estádio Barradão, Salvador
# 2             Estádio do Pacaembu, São Paulo
# 3      Estádio Independência, Belo Horizonte
# 4            Estádio Beira-Rio, Porto Alegre
#                        ...
# 375      Estádio do Maracanã, Rio de Janeiro
# 376              Estádio Castelão, Fortaleza
# 377                Allianz Parque, São Paulo
# 378            Arena do Grêmio, Porto Alegre
# 379           Estádio Ilha do Retiro, Recife
# Name: Estádio, Length: 380, dtype: object

# %%
renda = tabela['Renda (R$)']
renda
# Out:
# 0       418305.0
# 1       238994.0
# 2       526550.0
# 3        36293.0
# 4       796275.0
#          ...
# 375     139932.5
# 376    1128494.0
# 377    3514618.3
# 378    1450578.0
# 379     225305.0
# Name: Renda (R$), Length: 380, dtype: float64

# %%
tabela.groupby('Estádio')['Renda (R$)'].mean()
# Out:
# Estádio
# Allianz Parque, São Paulo                 2.184977e+06
# Arena Condá, Chapecó                      2.561482e+05
# Arena Corinthians, São Paulo              1.335615e+06
# Arena Fonte Nova, Salvador                3.916003e+05
# Arena Pernambuco, São Lourenço da Mata    5.939100e+05
# Arena da Baixada, Curitiba                2.660111e+05
# Arena do Grêmio, Porto Alegre             7.605969e+05
# Estádio Barradão, Salvador                9.639837e+04
# Estádio Beira-Rio, Porto Alegre           8.500737e+05
# Estádio Castelão, Fortaleza               6.231027e+05
# Estádio Engenhão, Rio de Janeiro          1.670227e+05
# Estádio Ilha do Retiro, Recife            1.826286e+05
# Estádio Indepedência, Belo Horizonte      1.131445e+05
# Estádio Independência, Belo Horizonte     1.854703e+05
# Estádio Mineirão, Belo Horizonte          3.253155e+05
# Estádio Nacional, Brasília                2.614730e+06
# Estádio Presidente Vargas, Fortaleza      1.030408e+05
# ...
